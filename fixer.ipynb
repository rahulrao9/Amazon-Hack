# %%
import pandas as pd

# %%
df = pd.read_csv("final\stage1_train.csv")

# %%
df.head(10)
# Out:
#    group_id                                         image_link  \
# 0    101697  https://m.media-amazon.com/images/I/31knj8wPlk...
# 1    101697  https://m.media-amazon.com/images/I/41FTsa9VyA...
# 2    101697  https://m.media-amazon.com/images/I/41MlQeYYuW...
# 3    101697  https://m.media-amazon.com/images/I/41NAtX8yLk...
# 4    101697  https://m.media-amazon.com/images/I/41OyX9WNNw...
# 5    101697  https://m.media-amazon.com/images/I/41QhPwGJME...
# 6    101697  https://m.media-amazon.com/images/I/41f3ysJyYW...
# 7    101697  https://m.media-amazon.com/images/I/41x7oPEmhx...
# 8    101697  https://m.media-amazon.com/images/I/51+sV+fV5r...
# 9    101697  https://m.media-amazon.com/images/I/51-f+FvRQ5...
#
#               depth  height             width  \
# 0               NaN     NaN   25.0 centimetre
# 1               NaN     NaN   37.5 centimetre
# 2  41.91 centimetre     NaN               NaN
# 3               NaN     NaN   20.0 centimetre
# 4               NaN     NaN   20.0 centimetre
# 5   25.0 centimetre     NaN               NaN
# 6   60.0 centimetre     NaN               NaN
# 7   50.0 centimetre     NaN               NaN
# 8  400.0 millimetre     NaN  300.0 millimetre
# 9               NaN     NaN   22.0 centimetre
#
#                                      embeddings_list  \
# 0  [array([array([0.14316815, 0.22907422, 0.13977...
# 1                                                 []
# 2                                                 []
# 3  [array([array([0.13295458, 0.29334748, 0.22904...
# 4                                                 []
# 5  [array([array([0.12027877, 0.21069154, 0.22630...
# 6  [array([array([0.11341421, 0.19739556, 0.11110...
# 7  [array([array([0.13828014, 0.19678386, 0.16277...
# 8  [array([array([0.13122417, 0.11933754, 0.13272...
# 9  [array([array([0.15472281, 0.24661653, 0.23351...
#
#                                            text_list  \
# 0              ['25.0 centimetre' '25.0 centimetre']
# 1                                                 []
# 2                                                 []
# 3              ['20.0 centimetre' '45.0 centimetre']
# 4                                                 []
# 5              ['25.0 centimetre' '25.0 centimetre']
# 6                          ['23.6 inch' '15.7 inch']
# 7                                ['50.0 centimetre']
# 8            ['300.0 millimetre' '400.0 millimetre']
# 9  ['6.5 centimetre' '8.66 inch' '4.44 inch' '3.1...
#
#                                           z_bar_list
# 0  [array([0.16407047, 0.14571945, 0.        , 1....
# 1                                                 []
# 2                                                 []
# 3  [array([0.15971769, 0.13871543, 0.        , 1....
# 4                                                 []
# 5  [array([0.16407047, 0.14571945, 0.        , 1....
# 6  [array([0.18230391, 0.17674984, 0.        , 1....
# 7  [array([0.17836258, 0.16981242, 0.        , 1....
# 8  [array([0.16771486, 0.15170387, 0.        , 1....
# 9  [array([0.13948781, 0.1082365 , 0.        , 1....

# %%
import pandas as pd
import ast
from datasets import load_dataset

def process_csv(input_file, output_file):
    # Read the CSV file
    dataframe = load_dataset("Hemabhushan/AmazonMLChallengeStage1", "P1")
    df = dataframe["train"].to_pandas()

    result = []
    for _, row in df.iterrows():
        # Parse the complex list structures
        embeddings_list = ast.literal_eval(row['embeddings_list'])
        print(type(embeddings_list))
        text_list = ast.literal_eval(row['text_list'])
        z_bar_list = ast.literal_eval(row['z_bar_list'])

        # print(embeddings_list)
        if len(text_list) > 0:
            for i in range(len(text_list)):
                # print(text_list)
                # Determine output
                # print(text_list)
                # print(len(embeddings_list[i]))
                parse_value = text_list[i]
                # print(parse_value)
                if parse_value == row['depth']:
                    output = [1, 0, 0, 0]
                elif parse_value == row['width']:
                    output = [0, 1, 0, 0]
                elif parse_value == row['height']:
                    output = [0, 0, 1, 0]
                else:
                    output = [0, 0, 0, 1]

                result.append({
                    'image_link': row['image_link'],
                    'group_id': row['group_id'],
                    'HEIGHT': row['height'],
                    'WIDTH': row['width'],
                    'DEPTH': row['depth'],
                    'EMBEDDING': embeddings_list[i][0] if i < len(embeddings_list) else None,
                    'PARSE_VALUE': parse_value,
                    'z_bar': z_bar_list[i] if i < len(z_bar_list) else None,
                    'output': output
                })

    # Create a new dataframe and save to CSV
    result_df = pd.DataFrame(result)
    result_df.to_csv(output_file, index=False)

# Usage
input_file = 'final//final_output.csv'  # Replace with your input file name
output_file = 'output.csv'  # Replace with your desired output file name
process_csv(input_file, output_file)
# Out:
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# 1
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
# 1
# <class 'list'>
# 1
# <class 'list'>
# 1
